# %%
import numpy as np
import pandas as pd
from math import exp
from sklearn.model_selection import train_test_split
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import matthews_corrcoef

# %%
def train_data():
    df = pd.read_csv('train.dat', delimiter='\t', names=["train_labels","train_sequence"])
    return df

# %%
def test_data():
    df = pd.read_csv('test.dat', delimiter='\t', names=["test_sequence"])
    return df

# %%
def extract_kmers_and_features(X, k=4):
    """
    Extract k-mers for each sequence in X and return the unique k-mers as features.
    """
    def kmer(seq, size):
        return [seq[x:x+size].lower() for x in range(0, len(seq) - size + 1)]

    # Extract k-mers for each sequence in X
    X_kmers = []
    all_kmers = set()
    for seq in X:
        kmers_seq = []
        for size in range(1, k):  # Generate k-mers from size 1 to k-1
            kmers_seq.extend(kmer(seq, size))
        X_kmers.append(' '.join(kmers_seq))
        all_kmers.update(kmers_seq)

    # Return k-mer sequences and sorted unique k-mers (feature set)
    return X_kmers, sorted(list(all_kmers))

# %%
df = train_data()
X, Y = df['train_sequence'].to_numpy(), df['train_labels'].to_numpy()
X_kmers, features = extract_kmers_and_features(X, k=4)
print(X_kmers)
# Out:
# ['d v e l d l v e i s p n a l p dv ve el ld dl lv ve ei is sp pn na al lp dve vel eld ldl dlv lve vei eis isp spn pna nal alp', 'k a d e e l f n k l f f g t ka ad de ee el lf fn nk kl lf ff fg gt kad ade dee eel elf lfn fnk nkl klf lff ffg fgt', 'f l v a l h l g t a f a l l w y f r k r w c a l v r g f f a s f g g r r n d d a h m m fl lv va al lh hl lg gt ta af fa al ll lw wy yf fr rk kr rw wc ca al lv vr rg gf ff fa as sf fg gg gr rr rn nd dd da ah hm mm flv lva val alh lhl hlg lgt gta taf afa fal all llw lwy wyf yfr frk rkr krw rwc wca cal alv lvr vrg rgf gff ffa fas asf sfg fgg ggr grr rrn rnd ndd dda dah ahm hmm', 'r d q m r a r i a d i t g v a i s r i a rd dq qm mr ra ar ri ia ad di it tg gv va ai is sr ri ia rdq dqm qmr mra rar ari ria iad adi dit itg tgv gva vai ais isr sri ria', 'r k r l q l l l l rk kr rl lq ql ll ll ll rkr krl rlq lql qll lll lll', 'p g f c v g e a s p l k s p g r r e l g h g n l a pg gf fc cv vg ge ea as sp pl lk ks sp pg gr rr re el lg gh hg gn nl la pgf gfc fcv cvg vge gea eas asp spl plk lks ksp spg pgr grr rre rel elg lgh ghg hgn gnl nla', 't p e e d t m v m k p l p p e p a p tp pe ee ed dt tm mv vm mk kp pl lp pp pe ep pa ap tpe pee eed edt dtm tmv mvm vmk mkp kpl plp lpp ppe pep epa pap', 's k d m r v q r sk kd dm mr rv vq qr skd kdm dmr mrv rvq vqr', 'i a a s i r h p l h c t ia aa as si ir rh hp pl lh hc ct iaa aas asi sir irh rhp hpl plh lhc hct', 'h p n l n l f a a g h d g g m i v f k hp pn nl ln nl lf fa aa ag gh hd dg gg gm mi iv vf fk hpn pnl nln lnl nlf lfa faa aag agh ghd hdg dgg ggm gmi miv ivf vfk', 'a l w k t l l k k v l k a y s p w t n f al lw wk kt tl ll lk kk kv vl lk ka ay ys sp pw wt tn nf alw lwk wkt ktl tll llk lkk kkv kvl vlk lka kay ays ysp spw pwt wtn tnf', 'a v k a t r av vk ka at tr avk vka kat atr', 'w n g a g a h t n y s t k s m r e d g g y e i i k k a i e wn ng ga ag ga ah ht tn ny ys st tk ks sm mr re ed dg gg gy ye ei ii ik kk ka ai ie wng nga gag aga gah aht htn tny nys yst stk tks ksm smr mre red edg dgg ggy gye yei eii iik ikk kka kai aie', 'l r r t r a a s q s i i p v d t k l s a g i t r i f p lr rr rt tr ra aa as sq qs si ii ip pv vd dt tk kl ls sa ag gi it tr ri if fp lrr rrt rtr tra raa aas asq sqs qsi sii iip ipv pvd vdt dtk tkl kls lsa sag agi git itr tri rif ifp', 'f e g t s g d g g d v i v t t e l e h h a n l i p w q e l a fe eg gt ts sg gd dg gg gd dv vi iv vt tt te el le eh hh ha an nl li ip pw wq qe el la feg egt gts tsg sgd gdg dgg ggd gdv dvi viv ivt vtt tte tel ele leh ehh hha han anl nli lip ipw pwq wqe qel ela', 'q d g i y t a h p v r t f d p p g g v q l s q r e p q s r h r e t a l qd dg gi iy yt ta ah hp pv vr rt tf fd dp pp pg gg gv vq ql ls sq qr re ep pq qs sr rh hr re et ta al qdg dgi giy iyt yta tah ahp hpv pvr vrt rtf tfd fdp dpp ppg pgg ggv gvq vql qls lsq sqr qre rep epq pqs qsr srh rhr hre ret eta tal', 'l n n e e e g a s g g a v h s d i g s s s s s s s p e p q e v t d t t e a p ln nn ne ee ee eg ga as sg gg ga av vh hs sd di ig gs ss ss ss ss ss ss sp pe ep pq qe ev vt td dt tt te ea ap lnn nne nee eee eeg ega gas asg sgg gga gav avh vhs hsd sdi dig igs gss sss sss sss sss sss ssp spe pep epq pqe qev evt vtd tdt dtt tte tea eap', 'k v f h m l d k d k s g f i kv vf fh hm ml ld dk kd dk ks sg gf fi kvf vfh fhm hml mld ldk dkd kdk dks ksg sgf gfi', 'k k h r k h r k h r k h g g s g g s k n l r r i i r k g i h i i k k y g kk kh hr rk kh hr rk kh hr rk kh hg gg gs sg gg gs sk kn nl lr rr ri ii ir rk kg gi ih hi ii ik kk ky yg kkh khr hrk rkh khr hrk rkh khr hrk rkh khg hgg ggs gsg sgg ggs gsk skn knl nlr lrr rri rii iir irk rkg kgi gih ihi hii iik ikk kky kyg', 'p h l s a t ph hl ls sa at phl hls lsa sat', 'k e g d t g s p e v q ke eg gd dt tg gs sp pe ev vq keg egd gdt dtg tgs gsp spe pev evq', 't f a e a l p r t g a v a g l d l g t k t i g v a v s d g l r g v a s p l t v i tf fa ae ea al lp pr rt tg ga av va ag gl ld dl lg gt tk kt ti ig gv va av vs sd dg gl lr rg gv va as sp pl lt tv vi tfa fae aea eal alp lpr prt rtg tga gav ava vag agl gl ...

# %%
def vectorize_kmers(X_kmers, features):
    """
    Convert k-mer sequences into vector representation based on features.
    """
    X_vector = np.zeros((len(X_kmers), len(features)))

    for i, kmers_seq in enumerate(X_kmers):
        count = Counter(kmers_seq.split())
        for kmer, cnt in count.items():
            if kmer in features:
                X_vector[i][features.index(kmer)] = cnt
        # Normalize the vector by dividing by the maximum value in the vector
        if np.max(X_vector[i]) > 0:
            X_vector[i] /= np.max(X_vector[i])

    return X_vector

# %%
X_vector = vectorize_kmers(X_kmers, features)

# %%
print(X_vector[0])
# Out:
# [0.33333333 0.         0.         ... 0.         0.         0.        ]

# %%
print(X_vector.shape)
# Out:
# (1566, 7264)

# %%
def oversample(X, Y):
    oversample = RandomOverSampler(sampling_strategy=0.2, random_state = 42)
    X_over, Y_over = oversample.fit_resample(X, Y)
    return X_over, Y_over

# %%
def relu(x):
    return np.maximum(0.0, x)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def forward_prop(X, W1, W2, W3, b1, b2, b3):

    z1 = relu(np.dot(X,W1) + b1)
    z2 = relu(np.dot(z1, W2) + b2)
    y_pred = sigmoid(np.dot(z2, W3) + b3)

    return z1, z2, y_pred
batch_size=128
neuronsl1, neuronsl2 =600 , 100
lambda_reg=0.0001
lr = 0.001

# %%
def compute_loss(y_pred, y, W1, W2, W3):
    return np.sum(((y-y_pred) ** 2) + lambda_reg * (np.linalg.norm(W1)+np.linalg.norm(W2)+np.linalg.norm(W3)))

# %%
def sigmoid_derivative(s_x):
    return np.multiply(s_x, np.subtract(1.0, s_x))

def relu_derivative(x):
    return np.where(x>0, 1, 0)

def backward_prop(X, Y, y_pred, Z1, Z2, W1, W2, W3, b1, b2, b3):
    delta_w3 = sigmoid_derivative(y_pred) * (Y-y_pred) #number of instances * number of output neurons
    delta_w2 = relu_derivative(Z2) * np.dot(delta_w3, W3.T)
    delta_w1 = relu_derivative(Z1) * np.dot(delta_w2, W2.T)

    W3 = W3 + (lr * (np.dot(Z2.T, delta_w3)))
    W3 = W3 - (lr * lambda_reg * np.sign(W3))
    b3 = b3 + (lr * np.dot(np.ones((1,delta_w3.shape[0])), delta_w3))
    W2 = W2 + (lr * (np.dot(Z1.T, delta_w2)))
    W2 = W2 - (lr * lambda_reg * np.sign(W2))
    b2 = b2 + (lr * np.dot(np.ones((1,delta_w2.shape[0])), delta_w2))
    W1 = W1 + (lr * (np.dot(X.T, delta_w1)))
    W1 = W1 - (lr * lambda_reg * np.sign(W1))
    b1 = b1 + (lr * np.dot(np.ones((1,delta_w1.shape[0])), delta_w1))
    return W1, W2, W3, b1, b2, b3

# %%
def train_fnn(X_train, y_train, features, epochs):
    # Initialize weights and biases
    b1 = np.zeros((1, neuronsl1))
    b2 = np.zeros((1, neuronsl2))
    b3 = np.zeros((1))
    R = np.random.RandomState(2025)
    W1 = R.normal(0, (2 / X_train.shape[1]), (len(features), neuronsl1))
    W2 = R.normal(0, (2 / neuronsl1), (neuronsl1, neuronsl2))
    W3 = R.normal(0, (2 / neuronsl2 + 1), (neuronsl2, 1))

    y_train = y_train[np.newaxis].T
    training_loss = []

    for epoch in range(epochs):
        # Training loop
        for i in range(0, len(X_train), batch_size):
            Xbatch = X_train[i:i + batch_size]
            ybatch = y_train[i:i + batch_size]
            Z1, Z2, y_pred = forward_prop(Xbatch, W1, W2, W3, b1, b2, b3)
            W1, W2, W3, b1, b2, b3 = backward_prop(Xbatch, ybatch, y_pred, Z1, Z2, W1, W2, W3, b1, b2, b3)

        # Calculate training loss
        Z1, Z2, y_pred = forward_prop(X_train, W1, W2, W3, b1, b2, b3)
        loss = compute_loss(y_pred, y_train, W1, W2, W3)
        training_loss.append(loss)
        print(f'Epoch {epoch}: Training Loss = {loss}')

    return W1, W2, W3, b1, b2, b3, training_loss

# %%
X_train, X_test, y_train, y_test = train_test_split(X_vector,
                                                    Y,
                                                    test_size = 0.20,
                                          random_state=42, stratify=Y)

X_over, Y_over = oversample(X_train, y_train)

Y_over = np.where(Y_over<0, 0, 1)
y_test = np.where(y_test<0, 0, 1)

W1, W2, W3, b1, b2, b3, training_loss = train_fnn(X_over, Y_over, features, epochs =200)
# Out:
# Epoch 0: Training Loss = 199.81349646576888
# Epoch 1: Training Loss = 194.77377825017473
# Epoch 2: Training Loss = 193.81555098015158
# Epoch 3: Training Loss = 193.33511426336986
# Epoch 4: Training Loss = 192.85838058539937
# Epoch 5: Training Loss = 192.25595592160698
# Epoch 6: Training Loss = 191.46051525961138
# Epoch 7: Training Loss = 190.4002526291585
# Epoch 8: Training Loss = 188.99206729993952
# Epoch 9: Training Loss = 187.1445813257156
# Epoch 10: Training Loss = 184.77314030849936
# Epoch 11: Training Loss = 181.86791388844753
# Epoch 12: Training Loss = 178.55316967456307
# Epoch 13: Training Loss = 175.99003633860403
# Epoch 14: Training Loss = 175.79602922377114
# Epoch 15: Training Loss = 174.47893044929006
# Epoch 16: Training Loss = 157.90320768345208
# Epoch 17: Training Loss = 131.76050988807546
# Epoch 18: Training Loss = 120.00603471337506
# Epoch 19: Training Loss = 110.69958294305113
# Epoch 20: Training Loss = 103.78798434290958
# Epoch 21: Training Loss = 98.93887720720882
# Epoch 22: Training Loss = 95.30590499811498
# Epoch 23: Training Loss = 91.53173677295062
# Epoch 24: Training Loss = 89.73558325018816
# Epoch 25: Training Loss = 88.10300483115935
# Epoch 26: Training Loss = 86.0979998362746
# Epoch 27: Training Loss = 84.5069961030133
# Epoch 28: Training Loss = 82.73942291431294
# Epoch 29: Training Loss = 81.2010633776959
# Epoch 30: Training Loss = 79.74110095849343
# Epoch 31: Training Loss = 78.40115469106142
# Epoch 32: Training Loss = 76.85379130737289
# Epoch 33: Training Loss = 75.08696659511247
# Epoch 34: Training Loss = 73.4511357662056
# Epoch 35: Training Loss = 71.88283042616217
# Epoch 36: Training Loss = 70.46566515349991
# Epoch 37: Training Loss = 69.01021469145124
# Epoch 38: Training Loss = 68.07987840215685
# Epoch 39: Training Loss = 66.20395720396897
# Epoch 40: Training Loss = 64.98320204834516
# Epoch 41: Training Loss = 63.37075086046536
# Epoch 42: Training Loss = 61.93843173584544
# Epoch 43: Training Loss = 60.28021471928282
# Epoch 44: Training Loss = 58.71788941322947
# Epoch 45: Training Loss = 57.5520771378857
# Epoch 46: Training Loss = 56.299954900710944
# Epoch 47: Training Loss = 55.000483268644075
# Epoch 48: Training Loss = 53.8706958352882
# Epoch 49: Training Loss = 52.84240413468192
# Epoch 50: Training Loss = 51.519731226869055
# Epoch 51: Training Loss = 50.49217904975946
# Epoch 52: Training Loss = 49.130431159989364
# Epoch 53: Training Loss = 48.019466665851695
# Epoch 54: Training Loss = 47.02494284234461
# Epoch 55: Training Loss = 45.84411866077417
# Epoch 56: Training Loss = 45.067745796465175
# Epoch 57: Training Loss = 44.01322219313607
# Epoch 58: Training Loss = 43.337828260969545
# Epoch 59: Training Loss = 42.38504026212016
# Epoch 60: Training Loss = 41.632528376783554
# Epoch 61: Training Loss = 40.77934718402099
# Epoch 62: Training Loss = 40.13736395101145
# Epoch 63: Training Loss = 39.39959938435031
# Epoch 64: Training Loss = 38.66704009140565
# Epoch 65: Training Loss = 37.898371560608
# Epoch 66: Training Loss = 37.366912715927114
# Epoch 67: Training Loss = 36.74328221899735
# Epoch 68: Training Loss = 36.108830466991684
# Epoch 69: Training Loss = 35.50447525951261
# Epoch 70: Training Loss = 34.89199350956586
# Epoch 71: Training Loss = 34.29230133684293
# Epoch 72: Training Loss = 33.744393863666986
# Epoch 73: Training Loss = 33.21981130615893
# Epoch 74: Training Loss = 32.70132348206529
# Epoch 75: Training Loss = 32.205218447244306
# Epoch 76: Training Loss = 31.746452498538325
# Epoch 77: Training Loss = 31.321283640451583
# Epoch 78: Training Loss = 30.88114856878207
# Epoch 79: Training Loss = 30.53284556257428
# Epoch 80: Training Loss = 30.090877115100874
# Epoch 81: Training Loss = 29.670528544261778
# Epoch 82: Training Loss = 29.224781400500685
# Epoch 83: Training Loss = 28.902819598414816
# Epoch 84: Training Loss = 28.501476123680845
# Epoch 85: Training Loss = 28.121960616568266
# Epoch 86: Training Loss = 27.800429674611557
# Epoch 87: Training Loss = 27.444972892189316
# Epoch 88: Training Loss = 27.097172974598475
# Epoch 89: Training Loss = 26.761489978103786
# Epoch 90: Training Loss = 26.455596688299572
# Epoch 91: Training Loss = 26.13159067503702
# Epoch 92: Training Loss = 25.799450712561427
# Epoch 93: Training Loss = 25.551728846389175
# Epoch 94: Training Loss = 25.223318916366516
# Epoch 95: Training Loss = 24.968245312341097
# Epoch 96: Training Loss = 24.660068023618376
# Epoch 97: Training Loss = 24.375503413911495
# Epoch 98: Training Loss = 24.134904099918188
# Epoch 99: Training Loss = 23.9703886553612
# Epoch 100: Training Loss = 23.613318241718076
# Epoch 101: Training Loss = 23.3754325871005
# Epoch 102: Training Loss = 23.18037526219865
# Epoch 103: Training Loss = 22.893609117779754
# Epoch 104: Training Loss = 22.70110668430834
# Epoch 105: Training Loss = 22.425590597708528
# Epoch 106: Training Loss = 22.239598850386677
# Epoch 107: Training Loss = 22.054109702953912
# Epoch 108: Training Loss = 21.792072852263967
# Epoch 109: Training Loss = 21.5861980261738
# Epoch 110: Training Loss = 21.393688447223504
# Epoch 111: Training Loss = 21.192715382026144
# Epoch 112: Training Loss = 21.02599066918829
# Epoch 113: Training Loss = 20.806353893278096
# Epoch 114: Training Loss = 20.586223946400473
# Epoch 115: Training Loss = 20.41103136240501
# Epoch 116: Training Loss = 20.25634300590726
# Epoch 117: Training Loss = 20.096386029116267
# Epoch 118: Training Loss = 19.954107509784293
# Epoch 119: Training Loss = 19.72293496243708
# Epoch 120: Training Loss = 19.54339990695501
# Epoch 121: Training Loss = 19.375001644139004
# Epoch 122: Training Loss = 19.284306134535697
# Epoch 123: Training Loss = 19.03657675574117
# Epoch 124: Training Loss = 18.89558193873259
# Epoch 125: Training Loss = 18.734276022362764
# Epoch 126: Training Loss = 18.55381026071696
# Epoch 127: Training Loss = 18.448344353298875
# Epoch 128: Training Loss = 18.283904567844928
# Epoch 129: Training Loss = 18.144705066362835
# Epoch 130: Training Loss = 17.993153069377584
# Epoch 131: Training Loss = 17.899778808004402
# Epoch 132: Training Loss = 17.690957452695628
# Epoch 133: Training Loss = 17.54192400341998
# Epoch 134: Training Loss = 17.462514388673863
# Epoch 135: Training Loss = 17.253882040102916
# Epoch 136: Training Loss = 17.112885034986583
# Epoch 137: Training Loss = 16.977239292821316
# Epoch 138: Training Loss = 16.841945853722393
# Epoch 139: Training Loss = 16.753620408784187
# Epoch 140: Training Loss = 16.574536624120455
# Epoch 141: Training Loss = 16.457861687927306
# Epoch 142: Training Loss = 16.31459700574515
# Epoch 143: Training Loss = 16.188153140860187
# Epoch 144: Training Loss = 16.09101848823688
# Epoch 145: Training Loss = 15.946182884356823
# Epoch 146: Training Loss = 15.862669574730305
# Epoch 147: Training Loss = 15.682889950724075
# Epoch 148: Training Loss = 15.601004687350933
# Epoch 149: Training Loss = 15.41823139107683
# Epoch 150: Training Loss = 15.341911722997924
# Epoch 151: Training Loss = 15.184046484994699
# Epoch 152: Training Loss = 15.112184113451658
# Epoch 153: Training Loss = 14.928518234723716
# Epoch 154: Training Loss = 14.875683090353201
# Epoch 155: Training Loss = 14.70071971103911
# Epoch 156: Training Loss = 14.627808645858636
# Epoch 157: Training Loss = 14.482509432127664
# Epoch 158: Training Loss = 14.408541143324918
# Epoch 159: Training Loss = 14.24720262888681
# Epoch 160: Training Loss = 14.194689979403606
# Epoch 161: Training Loss = 14.04072240356062
# Epoch 162: Training Loss = 13.985202381996666
# Epoch 163: Training Loss = 13.838290070318394
# Epoch 164: Training Loss = 13.803837975967216
# Epoch 165: Training Loss = 13.65309903806116
# Epoch 166: Training Loss = 13.617480241576406
# Epoch 167: Training Loss = 13.467412712209356
# Epoch 168: Training Loss = 13.431138673170537
# Epoch 169: Training Loss = 13.294792897507591
# Epoch 170: Training Loss = 13.250617447746134
# Epoch 171: Training Loss = 13.120391464901925
# Epoch 172: Training Loss = 13.085899694629717
# Epoch 173: Training Loss = 12.951991379647556
# Epoch 174: Training Loss = 12.912855135073531
# Epoch 175: Training Loss = 12.792773212640316
# Epoch 176: Training Loss = 12.76009384375873
# Epoch 177: Training Loss = 12.642988612068471
# Epoch 178: Training Loss = 12.61085624150942
# Epoch 179: Training Loss = 12.488311128692605
# Epoch 180: Training Loss = 12.465558746413237
# Epoch 181: Training Loss = 12.347255433740859
# Epoch 182: Training Loss = 12.3065332386068
# Epoch 183: Training Loss = 12.213009792367371
# Epoch 184: Training Loss = 12.187188900087275
# Epoch 185: Training Loss = 12.075812789822088
# Epoch 186: Training Loss = 12.028889208789291
# Epoch 187: Training Loss = 11.968415338525363
# Epoch 188: Training Loss = 11.898752020133339
# Epoch 189: Training Loss = 11.832374330498126
# Epoch 190: Training Loss = 11.777466090420015
# Epoch 191: Training Loss = 11.708718434426995
# Epoch 192: Training Loss = 11.660146106353057
# Epoch 193: Training Loss = 11.600705216752537
# Epoch 194: Training Loss = 11.537780132061993
# Epoch 195: Training Loss = 11.482520710389696
# Epoch 196: Training Loss = 11.42501745072316
# Epoch 197: Training Loss = 11.386670648053414
# Epoch 198: Training Loss = 11.318519845311425
# Epoch 199: Training Loss = 11.266307579854747

# %%
def predict(X_test, y_test, W1, W2, W3, b1, b2, b3):
    # Predict on the validation set
    Z1, Z2, y_pred = forward_prop(X_test, W1, W2, W3, b1, b2, b3)
    y_pred = np.where(y_pred < 0.6, 0, 1)
    validation_mcc = matthews_corrcoef(y_pred, y_test[np.newaxis].T)
    print(f'Validation MCC = {validation_mcc}')
    return y_pred, validation_mcc

# %%
y_pred, validation_mcc = predict(X_test, y_test, W1, W2, W3, b1, b2, b3)
# Out:
# Validation MCC = 0.9215784215784216

# %%
df = test_data()
X_t = df['test_sequence'].to_numpy()
X_kmers_t, features_t = extract_kmers_and_features(X_t, k=4)
X_vector_t = vectorize_kmers(X_kmers_t, features)

# %%
Z1, Z2, y_pred = forward_prop(X_vector, W1, W2, W3, b1, b2, b3)
y_pred = np.where(y < 0.6, -1, 1)
np.savetxt('predictions.dat', y, delimiter='\n',fmt='%i')

# %%
print(X_vector_t.shape)
# Out:
# (392, 7264)
